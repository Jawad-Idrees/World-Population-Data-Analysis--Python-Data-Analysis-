# %%
import pandas as pd
import seaborn as sns

import matplotlib as plt

# %% [markdown]
# ### The dataset as well as the analysis applied to the dataset in this notebook is from a Youtube tutorial
# ### I have introduced some parts of my own but the majority of the steps come from that tutorial.

# %%
df=pd.read_csv(r"world_population.csv")

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %% [markdown]
# ## Count total Records

# %%
df.count()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                      234
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     232
# Density (per km²)              230
# Growth Rate                    232
# World Population Percentage    234
# dtype: int64

# %% [markdown]
# ## Count Null Values

# %%
df.isnull().sum()
# Out:
# Rank                           0
# CCA3                           0
# Country                        0
# Capital                        0
# Continent                      0
# 2022 Population                4
# 2020 Population                1
# 2015 Population                4
# 2010 Population                7
# 2000 Population                7
# 1990 Population                5
# 1980 Population                5
# 1970 Population                4
# Area (km²)                     2
# Density (per km²)              4
# Growth Rate                    2
# World Population Percentage    0
# dtype: int64

# %% [markdown]
# ## Check Countries

# %%
df.sort_values(by='Rank', ascending=True)
# Out:
#      Rank CCA3           Country           Capital      Continent  \
# 41      1  CHN             China           Beijing           Asia
# 92      2  IND             India         New Delhi           Asia
# 221     3  USA     United States  Washington, D.C.  North America
# 93      4  IDN         Indonesia           Jakarta           Asia
# 156     5  PAK          Pakistan         Islamabad           Asia
# ..    ...  ...               ...               ...            ...
# 137   230  MSR        Montserrat            Brades  North America
# 64    231  FLK  Falkland Islands           Stanley  South America
# 150   232  NIU              Niue             Alofi        Oceania
# 209   233  TKL           Tokelau          Nukunonu        Oceania
# 226   234  VAT      Vatican City      Vatican City         Europe
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 41      1.425887e+09     1.424930e+09     1.393715e+09     1.348191e+09
# ...

# %% [markdown]
# ## Sort records by Area

# %%
df.sort_values(by='Area (km²)', ascending=False)
# Out:
#      Rank CCA3        Country           Capital      Continent  \
# 171     9  RUS         Russia            Moscow         Europe
# 35     39  CAN         Canada            Ottawa  North America
# 41      1  CHN          China           Beijing           Asia
# 221     3  USA  United States  Washington, D.C.  North America
# 27      7  BRA         Brazil          Brasilia  South America
# ..    ...  ...            ...               ...            ...
# 76    219  GIB      Gibraltar         Gibraltar         Europe
# 134   217  MCO         Monaco            Monaco         Europe
# 226   234  VAT   Vatican City      Vatican City         Europe
# 183    72  SEN        Senegal             Dakar         Africa
# 227    51  VEN      Venezuela           Caracas  South America
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 171     1.447133e+08     1.456173e+08     1.446684e+08     1.432426e+08
# ...

# %% [markdown]
# ## Check nulls for a specific field

# %%
df['Capital'].isnull().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#              Rank  2022 Population  2020 Population  2015 Population  \
# count  234.000000     2.300000e+02     2.330000e+02     2.300000e+02
# mean   117.500000     3.463225e+07     3.360071e+07     3.206600e+07
# std     67.694165     1.378892e+08     1.358732e+08     1.315071e+08
# min      1.000000     5.100000e+02     5.200000e+02     5.640000e+02
# 25%     59.250000     4.197385e+05     4.064710e+05     3.942950e+05
# 50%    117.500000     5.762857e+06     5.456681e+06     5.244415e+06
# 75%    175.750000     2.265372e+07     2.152263e+07     1.973085e+07
# max    234.000000     1.425887e+09     1.424930e+09     1.393715e+09
#
#        2010 Population  2000 Population  1990 Population  1980 Population  \
# count     2.270000e+02     2.270000e+02     2.290000e+02     2.290000e+02
# mean      3.027016e+07     2.684050e+07     1.933046e+07     1.628288e+07
# std       1.260742e+08     1.133525e+08     8.130962e+07     6.934547e+07
# ...

# %% [markdown]
# #### A big usage of describe() is that it  can help detect outliers with its own way as you can analyze the difference between 50% data and 75% data and see if there is any abnormality.

# %%
df.count()
# Out:
# Rank                           234
# CCA3                           234
# Country                        234
# Capital                        234
# Continent                      234
# 2022 Population                230
# 2020 Population                233
# 2015 Population                230
# 2010 Population                227
# 2000 Population                227
# 1990 Population                229
# 1980 Population                229
# 1970 Population                230
# Area (km²)                     232
# Density (per km²)              230
# Growth Rate                    232
# World Population Percentage    234
# dtype: int64

# %%
df2=df.dropna()

# %%
df2
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 228    16  VNM            Vietnam             Hanoi      Asia
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %% [markdown]
# ## Dropping the index column

# %%
dg=pd.read_csv(r"world_population.csv", index_col=0)

# %%
dg
# Out:
#      CCA3            Country           Capital Continent  2022 Population  \
# Rank
# 36    AFG        Afghanistan             Kabul      Asia       41128771.0
# 138   ALB            Albania            Tirana    Europe        2842321.0
# 34    DZA            Algeria           Algiers    Africa       44903225.0
# 213   ASM     American Samoa         Pago Pago   Oceania          44273.0
# 203   AND            Andorra  Andorra la Vella    Europe          79824.0
# ...   ...                ...               ...       ...              ...
# 226   WLF  Wallis and Futuna          Mata-Utu   Oceania          11572.0
# 172   ESH     Western Sahara          El Aaiún    Africa         575986.0
# 46    YEM              Yemen             Sanaa      Asia       33696614.0
# 63    ZMB             Zambia            Lusaka    Africa       20017675.0
# 74    ZWE           Zimbabwe            Harare    Africa       16320537.0
#
# ...

# %%
df_sorted=sorted(df.columns)

# %%
df_sorted_columns=df[df_sorted]

# %%
df_sorted_columns
# Out:
#      1970 Population  1980 Population  1990 Population  2000 Population  \
# 0         10752971.0       12486631.0       10694796.0       19542982.0
# 1          2324731.0        2941651.0        3295066.0        3182021.0
# 2         13795915.0       18739378.0       25518074.0       30774621.0
# 3            27075.0          32886.0          47818.0          58230.0
# 4            19860.0          35611.0          53569.0          66097.0
# ..               ...              ...              ...              ...
# 229           9377.0          11315.0          13454.0          14723.0
# 230          76371.0         116775.0         178529.0         270375.0
# 231        6843607.0        9204938.0       13375121.0       18628700.0
# 232        4281671.0        5720438.0        7686401.0        9891136.0
# 233        5202918.0        7049926.0       10113893.0       11834676.0
#
#      2010 Population  2015 Population  2020 Population  2022 Population  \
# ...

# %% [markdown]
# ## Setting float options

# %%
pd.set_option('display.float_format', lambda x: '%.f'%x)

# %% [markdown]
# ## Data types

# %%
df.dtypes
# Out:
# Rank                             int64
# CCA3                            object
# Country                         object
# Capital                         object
# Continent                       object
# 2022 Population                float64
# 2020 Population                float64
# 2015 Population                float64
# 2010 Population                float64
# 2000 Population                float64
# 1990 Population                float64
# 1980 Population                float64
# 1970 Population                float64
# Area (km²)                     float64
# Density (per km²)              float64
# Growth Rate                    float64
# World Population Percentage    float64
# dtype: object

# %% [markdown]
# ## Finding correlation

# %%
# To convert data type of a column to int.
#df['column_name'] = pd.to_numeric(df['column_name'], errors='coerce')
df_for_corr= df.select_dtypes(include=[np.number])


#To select columns that have numeric data types
#numeric_df = df.select_dtypes(include=[np.number])

# %% [markdown]
# ### We have to get columns with numeric type so that we can apply .corr() which was causing error otherwise.

# %%
df_for_corr.corr()
# Out:
#                              Rank  2022 Population  2020 Population  \
# Rank                            1               -0               -0
# 2022 Population                -0                1                1
# 2020 Population                -0                1                1
# 2015 Population                -0                1                1
# 2010 Population                -0                1                1
# 2000 Population                -0                1                1
# 1990 Population                -0                1                1
# 1980 Population                -0                1                1
# 1970 Population                -0                1                1
# Area (km²)                     -0                0                0
# Density (per km²)               0               -0               -0
# Growth Rate                    -0               -0               -0
# World Population Percentage    -0                1                1
#
# ...

# %% [markdown]
# #### Plotting correlation

# %%
sns.heatmap(df_for_corr.corr(), annot= True)
plt.rcParams['figure.figsize']= (10,5)

# %% [markdown]
# #### Transposing can be handy often

# %%
#df2= df.transpose()

# %% [markdown]
# ## Conditional DataFrame

# %%
df2=df[df['Continent'].str.contains('Oceania')]

# %% [markdown]
# ## Column Indexing

# %%
df2= df[df.columns[5:13]]
# indexing starts from 0

# %%
df3=df.groupby('Continent').sum()
df3
# Out:
#                Rank                                               CCA3  \
# Continent
# Africa         5253  DZAAGOBENBWABFABDICMRCPVCAFTCDCOMDJICODEGYGNQE...
# Asia           3878  AFGARMAZEBHRBGDBTNBRNKHMCHNGEOHKGINDIDNIRNIRQI...
# Europe         6225  ALBANDAUTBLRBELBIHBGRHRVCYPCZEDNKESTFROFINFRAD...
# North America  6437  AIAATGABWBHSBRBBLZBMUVGBCANCYMCRICUBCUWDMADOMS...
# Oceania        4336  ASMAUSCOKFJIPYFGUMKIRMHLFSMNRUNCLNZLNIUNFKPLWP...
# South America  1366         ARGBOLBRACHLCOLECUFLKGUFGUYPRYPERSURURYVEN
#
#                                                          Country  \
# Continent
# Africa         AlgeriaAngolaBeninBotswanaBurkina FasoBurundiC...
# Asia           AfghanistanArmeniaAzerbaijanBahrainBangladeshB...
# Europe         AlbaniaAndorraAustriaBelarusBelgiumBosnia and ...
# North America  AnguillaAntigua and BarbudaArubaBahamasBarbado...
# Oceania        American SamoaAustraliaCook IslandsFijiFrench ...
# ...

# %%
df3.columns[3:9]
# Out:
# Index(['Capital', '2022 Population', '2020 Population', '2015 Population',
#        '2010 Population', '2000 Population'],
#       dtype='object')

# %%
df3=df3[df3.columns[4:12]]
df3
# Out:
#                2022 Population  2020 Population  2015 Population  \
# Continent
# Africa              1425529262       1360671810       1156663993
# Asia                4720041978       4652801584       4458250182
# Europe               737713219        745792196        736345252
# North America        600296136        594236593        570383850
# Oceania               45020499         43933426         40403283
# South America        436816608        431530043        413134396
#
#                2010 Population  2000 Population  1990 Population  \
# Continent
# Africa              1020502655        817508493        637110013
# Asia                4187125190       3706718415       2334719776
# Europe               735613934        726066600        709689789
# North America        542720651        486069584        421266425
# Oceania               37102764         31222778         26743822
# South America        348262142        325206553        297146415
#
# ...

# %%
df4= df3[df3.columns[::-1]]
df4
# Out:
#                1970 Population  1980 Population  1990 Population  \
# Continent
# Africa               361194640        480817791        637110013
# Asia                2104314136       1933360000       2334719776
# Europe               655923991        681600217        709689789
# North America        315434606        368293361        421266425
# Oceania               19480270         22920240         26743822
# South America        192947156        241789006        297146415
#
#                2000 Population  2010 Population  2015 Population  \
# Continent
# Africa               817508493       1020502655       1156663993
# Asia                3706718415       4187125190       4458250182
# Europe               726066600        735613934        736345252
# North America        486069584        542720651        570383850
# Oceania               31222778         37102764         40403283
# South America        325206553        348262142        413134396
#
# ...

# %% [markdown]
# .\
# .
# We are first going to draw a plot that does not make nuch sense. Then we take transpose of our dataset and plot again which provides way more meaningful visualization.

# %%
df4.plot()
# Out:
# <Axes: xlabel='Continent'>

# %%
df5=df4.transpose()

# %%
df5
# Out:
# Continent           Africa       Asia    Europe  North America  Oceania  \
# 1970 Population  361194640 2104314136 655923991      315434606 19480270
# 1980 Population  480817791 1933360000 681600217      368293361 22920240
# 1990 Population  637110013 2334719776 709689789      421266425 26743822
# 2000 Population  817508493 3706718415 726066600      486069584 31222778
# 2010 Population 1020502655 4187125190 735613934      542720651 37102764
# 2015 Population 1156663993 4458250182 736345252      570383850 40403283
# 2020 Population 1360671810 4652801584 745792196      594236593 43933426
# 2022 Population 1425529262 4720041978 737713219      600296136 45020499
#
# Continent        South America
# 1970 Population      192947156
# 1980 Population      241789006
# 1990 Population      297146415
# 2000 Population      325206553
# 2010 Population      348262142
# 2015 Population      413134396
# 2020 Population      431530043
# 2022 Population      436816608

# %%
df5.plot()
# Out:
# <Axes: >

# %% [markdown]
# #### So you get the whole point. We have developed a visualization that describes the trend or the growth rate continent wise.
#
# #### Continent Asia has is the most populated continent as well as the fastest growing.
